# %%
# !python3 plane.py --dir=./results/plane_data \
    --ckpt=./runs/ResNet8_CIFAR10_CP_Bezier_1_2/checkpoint-50.pt \
    --model=ResNet8 \
    --curve=Bezier \
    --num_bends=3 \
    --dataset=CIFAR10 \
    --data_path=./data \
    --grid_points=11 \
    --curve_points=11 \
    --batch_size=128
# Out:
# Loaded checkpoint into curve_model with strict=True
# Weight space dimensionality: 78042
# /Users/theoxenakis/Downloads/GoCart/MIT/67960_DL/dnn-mode-connectivity/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ----------  ----------  ------------  -----------  -----------------  ----------  ----------------
#          X           Y    Train loss    Train nll    Train error (%)    Test nll    Test error (%)
# ----------  ----------  ------------  -----------  -----------------  ----------  ----------------
#    -8.2544     -7.5520        0.3468       0.3385            11.7933      0.3073           10.9800
#    -8.2544     -2.2656        0.3500       0.3420            11.9489      0.3314           11.9200
#    -8.2544      3.0208        0.4548       0.4469            15.1956      0.4376           15.3200
# ...

# %%
# !python3 plane.py --dir=/content/drive/MyDrive/mode_connectivity_runs/results/plane_data \
    --ckpt=/content/drive/MyDrive/mode_connectivity_runs/{MODEL}_{DATASET}_CP_PolyChain_{SEED1}_{SEED2}/checkpoint-50.pt \
    --model=$MODEL \
    --curve=Bezier \
    --num_bends=3 \
    --dataset=$DATASET \
    --data_path=./data \
    --grid_points=21 \
    --curve_points=61 \
    --batch_size=128
